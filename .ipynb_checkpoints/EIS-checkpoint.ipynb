# %%
# !pip install pyodbc sqlalchemy
# Out:
# Requirement already satisfied: pyodbc in c:\users\sujon\appdata\local\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: sqlalchemy in c:\users\sujon\appdata\local\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\sujon\appdata\local\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sujon\appdata\local\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQL Server Native Client 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'ODBC Driver 18 for SQL Server']

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=103.115.242.30;"   # your server IP
    "DATABASE=MGERP;"
    "UID=RND;"
    "PWD=*userdts*;"
    "TrustServerCertificate=yes;"
)

cursor = conn.cursor()
cursor.execute("SELECT TOP 5 * FROM your_table")

for row in cursor.fetchall():
    print(row)
# Out:
# Connected successfully!

# %%
Server: 103.115.242.30,1437
User: sa
Password:  *userdts*

# %%
from sqlalchemy import create_engine
import pandas as pd
import urllib

server = "192.168.3.122"
database = "DBMGERP"

params = urllib.parse.quote_plus(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    f"SERVER={server},1433;"
    f"DATABASE={database};"
    "Trusted_Connection=yes;"
)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# %%
engine
# Out:
# Engine(mssql+pyodbc:///?odbc_connect=DRIVER%3D%7BODBC+Driver+18+for+SQL+Server%7D%3BSERVER%3D192.168.3.122%2C1433%3BDATABASE%3DDBMGERP%3BTrusted_Connection%3Dyes%3B)
